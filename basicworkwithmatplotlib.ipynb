# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/diabetes (1).csv')

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.shape
# Out:
# (768, 9)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.sample()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 322            0      124             70             20        0  27.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 322                     0.254   36        1

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df.loc[df['Outcome'] == 1]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 2              8      183             64              0        0  23.3
# 4              0      137             40             35      168  43.1
# 6              3       78             50             32       88  31.0
# 8              2      197             70             45      543  30.5
# ..           ...      ...            ...            ...      ...   ...
# 755            1      128             88             39      110  36.5
# 757            0      123             72              0        0  36.3
# 759            6      190             92              0        0  35.5
# 761            9      170             74             31        0  44.0
# 766            1      126             60              0        0  30.1
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.loc[df['BloodPressure']== 0].__len__()
# Out:
# 35

# %%
df.loc[df['Insulin']== 0].__len__()
# Out:
# 374

# %%
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
DF1 = df.set_index('BMI')

# %%
DF1
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin  \
# BMI
# 33.6            6      148             72             35        0
# 26.6            1       85             66             29        0
# 23.3            8      183             64              0        0
# 28.1            1       89             66             23       94
# 43.1            0      137             40             35      168
# ...           ...      ...            ...            ...      ...
# 32.9           10      101             76             48      180
# 36.8            2      122             70             27        0
# 26.2            5      121             72             23      112
# 30.1            1      126             60              0        0
# 30.4            1       93             70             31        0
#
#       DiabetesPedigreeFunction  Age  Outcome
# BMI
# 33.6                     0.627   50        1
# 26.6                     0.351   31        0
# ...

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 9

# %%
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
df.describe(include= 'all')
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# ...

# %%
df['BloodPressure'].value_counts().idxmax()
# Out:
# np.int64(70)

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
plt.bar([0,1],df['Outcome'].value_counts())
plt.show()

# %%
df.loc[(df['BloodPressure'] == 0)&(df['Outcome'] == 1)]['Age'].min()
# Out:
# 23

# %%
df.loc[(df['BloodPressure'] == 0)&(df['Pregnancies'] == 1)]['Age'].min()
# Out:
# 41

# %%
df['Pregnancies'].value_counts()
# Out:
# Pregnancies
# 1     135
# 0     111
# 2     103
# 3      75
# 4      68
# 5      57
# 6      50
# 7      45
# 8      38
# 9      28
# 10     24
# 11     11
# 13     10
# 12      9
# 14      2
# 17      1
# 15      1
# Name: count, dtype: int64

# %%
g = df.groupby('Outcome')
g.max().drop( columns = ['BMI','Glucose'])
# Out:
#          Pregnancies  BloodPressure  SkinThickness  Insulin  \
# Outcome
# 0                 13            122             60      744
# 1                 17            114             99      846
#
#          DiabetesPedigreeFunction  Age
# Outcome
# 0                           2.329   81
# 1                           2.420   70

# %%
df.loc[df['Insulin'].between(300,400)]
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 53             8      176             90             34      300  33.7
# 54             7      150             66             42      342  34.7
# 56             7      187             68             39      304  37.7
# 139            5      105             72             29      325  36.9
# 199            4      148             60             27      318  30.9
# 231            6      134             80             37      370  46.2
# 258            1      193             50             16      375  25.9
# 296            2      146             70             38      360  28.0
# 360            5      189             64             33      325  31.2
# 375           12      140             82             43      325  39.2
# 412            1      143             84             23      310  42.4
# 480            3      158             70             30      328  35.5
# ...

# %%
X = [2,3,4,4,5,6]
Y = [4,5,6,3,5,7]
plt.plot(X,Y)
plt.show()

# %%
X = [2,3,4,4,5,6]
Y = [4,5,6,3,5,7]
plt.scatter(X,Y)
plt.show()
plt.plot(X,Y)
plt.show()

# %%
X = [2,3,4,4,5,6]
Y = [4,5,6,3,5,7]
plt.plot(X,Y)
plt.title('Line Plot')
plt.xlabel('X-Axis')
plt.ylabel('Y-Axis')
plt.show()

# %%
X = [2,3,4,4,5,6]
Y = [4,5,6,3,5,7]
plt.plot(X,Y)
plt.title('Line Plot',color = "green",fontsize = 20)
plt.xlabel('X-Axis',color = "green",fontsize = 20)
plt.ylabel('Y-Axis',color = "green",fontsize = 20)
plt.show()

# %%
X = [2,3,4,4,5,6]
Y = [4,5,6,3,5,7]
plt.plot(X,Y,color = 'red',linewidth = 2, marker = "*",ms = 20,mfc = 'black')
plt.title('Line Plot',color = "green",fontsize = 20)
plt.xlabel('X-Axis',color = "green",fontsize = 20)
plt.ylabel('Y-Axis',color = "green",fontsize = 20)
plt.show()

# %%
X = [2,3,4,4,5,6]
Y = [4,5,6,3,5,7]
plt.plot(X,Y,"ro--")
plt.title('Line Plot',color = "green",fontsize = 20)
plt.xlabel('X-Axis',color = "green",fontsize = 20)
plt.ylabel('Y-Axis',color = "green",fontsize = 20)
plt.legend(['REGRESSION LINE'])
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
X = [2,3,4,4,5,6]
Y = [4,5,6,3,5,7]
plt.plot(X,Y,"ro--")
plt.title('Line Plot',color = "green",fontsize = 20)
plt.xlabel('X-Axis',color = "green",fontsize = 20)
plt.ylabel('Y-Axis',color = "green",fontsize = 20)
plt.legend(['REGRESSION LINE'])
plt.show()

# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('ggplot')
X = [2,3,4,4,5,6]
Y = [4,5,6,3,5,7]
plt.plot(X,Y,"ro--")
plt.title('Line Plot',color = "green",fontsize = 20)
plt.xlabel('X-Axis',color = "green",fontsize = 20)
plt.ylabel('Y-Axis',color = "green",fontsize = 20)
plt.legend(['REGRESSION LINE'])
plt.grid(color = 'black',linewidth = 1,linestyle = ":")
plt.show()

# %%
import matplotlib.pyplot as plt
course = ['python','hindi','english','maths']
marks = [40,60,70,80]
plt.bar(course,marks)
plt.xlabel('courses',color = 'black')
plt.ylabel('marks',color= 'black')
plt.show()

# %%
import matplotlib.pyplot as plt
course = ['python','hindi','english','maths']
course = ['python','hindi','bio','maths']
marks = [40,60,70,80]
marks = [50,60,90,40]
plt.bar(course,marks,color = 'green',width = 0.2)
plt.xlabel('courses',color = 'black')
plt.ylabel('marks',color= 'black')
plt.show()

# %%
import matplotlib.pyplot as plt
course = ['python','hindi','english','maths']
marks = [40,60,70,80]
plt.bar(course,marks, color = ['green','blue','pink'],width = 0.2, edgecolor = 'black',
linewidth = 5,linestyle = ':')
plt.xlabel('courses',color = 'black')
plt.ylabel('marks',color= 'black')
plt.show()

# %%
import matplotlib.pyplot as plt
course = ['python','hindi','english','maths']
imarks = [40,63,100,80]
pmark = [50,60,90,40]
plt.bar(course,imarks, width = 0.2, label = 'Indian')
plt.bar(course,pmark, width = 0.2)
plt.xlabel('courses',color = 'black')
plt.ylabel('marks',color= 'black')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
course_index = np.arange(4)
course = ['python','hindi','english','maths']
imarks = [40,60,70,80]
pmark = [50,60,90,40]
plt.bar(course_index,imarks,width = 0.2)
plt.bar(course_index+0.18,pmark,width = 0.2)
plt.xlabel('courses',color = 'black')
plt.ylabel('marks',color= 'black')
plt.show()

# %%
plt.pie([10,20,30])
plt.show()

# %%
course = ['python','hindi','english','maths']
marks = [40,60,70,80]
plt.pie(marks,labels = course,autopct ="%0.2f%%",\
        colors = ['red','green','blue','pink'])
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
X = np.arange(10,20,0.5)
Y = np.arange(40,50,0.5)
plt.scatter(X,Y)
plt.show()

# %%
plt.figure(figsize = (15,10))
plt.pie([10,20,30,40],labels = list("pqrs"))
plt.show()

# %%
import matplotlib.pyplot as plt
X = np.arange(10,20,0.5)
Y = np.arange(40,50,0.5)
plt.scatter(X,Y)
plt.subplot(2,2,1)
plt.plot(X,Y)
plt.subplot(2,2,3)
plt.pie([10,20,30])
plt.subplot(2,2,2)
plt.scatter(X,Y)
plt.show()
